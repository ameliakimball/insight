# %%
import pandas as pd
import matplotlib.pyplot as plt

#read in data 
chidat = pd.read_csv("chicago_adopted_20k_Jan_20.csv") 
stldat = pd.read_csv("StL_adopted_20k_Jan_21.csv")
inddat = pd.read_csv("Indy_adopted_20k_Jan_21.csv")

petdat = pd.concat([chidat, stldat, inddat])

#drop variables that aren't interesting out of the gate

petdat = petdat.drop(['Unnamed: 0',
                      'url',
                      'type',
                      'species',
                      'tags',
                      'description',
                      'attributes.declawed',
                      'contact.phone',
                      'contact.address.address1',
                      'contact.address.address2',
                      'contact.address.state',
                      'contact.address.postcode',
                      'contact.address.country',
                      'photos',
                      'colors.primary',
                      'colors.secondary',
                      'colors.tertiary',
                      '_links.self.href',
                      '_links.type.href'], axis=1)


#drop variables that have lots of NAs, leaving only features with no NAs (well, name has 1???)

petdat = petdat.drop(['breeds.secondary',
                      'environment.children',
                      'environment.dogs',
                      'environment.cats',
                      'contact.email',
                      'coat'], axis=1)


#reformat dates and calculate difference in dates (= target variable)

fmt ='%Y-%m-%dT%H:%M:%S+0000'
petdat['published_at'] =  pd.to_datetime(petdat['published_at'], format=fmt)
petdat['status_changed_at'] =  pd.to_datetime(petdat['status_changed_at'], format=fmt)
petdat['time_diff'] = petdat['status_changed_at'] - petdat['published_at']
petdat['target_hour'] = petdat.time_diff.astype('timedelta64[h]')

petdat.head()


#take out outliers
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          id organization_id    age  gender    size       name   status  \
# 0  47151520           WI463   Baby  Female  Medium      Pacey  adopted
# 1  47150453           IL663   Baby  Female  Medium       Lola  adopted
# 2  47148767           IL782  Adult  Female  Medium   Mama Mia  adopted
# 3  47147717            WI13  Young    Male  Medium  Mason- PS  adopted
# 4  47146215           IL496  Young    Male  Medium     Speedo  adopted
#
#     status_changed_at        published_at  distance  ... breeds.mixed  \
# 0 2020-01-19 20:35:12 2020-01-19 19:37:30   62.0190  ...         True
# 1 2020-01-20 23:30:53 2020-01-19 14:28:50   37.9186  ...         True
# 2 2020-01-19 14:26:53 2020-01-18 21:33:03   35.4803  ...         True
# 3 2020-01-18 22:35:29 2020-01-18 18:35:31   78.8180  ...        False
# 4 2020-01-18 18:09:29 2020-01-18 03:50:20    7.2643  ...        False
#
#    breeds.unknown  attributes.spayed_neutered  attributes.house_trained  \
# 0           False                        True                     False
# 1           False                        True                      True
# 2           False                       False                     False
# 3           False                       False                     False
# 4           False                        True                     False
#
#    attributes.special_needs  attributes.shots_current  contact.address.city  \
# 0                     False                      True                Racine
# 1                     False                      True           Hainesville
# 2                     False                     False                Joliet
# 3                     False                      True        West Milwaukee
# 4                     False                      True               Chicago
#
#   _links.organization.href       time_diff target_hour
# 0  /v2/organizations/wi463 0 days 00:57:42         0.0
# 1  /v2/organizations/il663 1 days 09:02:03        33.0
# 2  /v2/organizations/il782 0 days 16:53:50        16.0
# 3   /v2/organizations/wi13 0 days 03:59:58         3.0
# 4  /v2/organizations/il496 0 days 14:19:09        14.0
#
# [5 rows x 21 columns]
